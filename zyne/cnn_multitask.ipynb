# %%
import os
import glob
import numpy as np
import pandas as pd
import librosa
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Dense, Dropout,
    BatchNormalization, GlobalAveragePooling2D, Input
)
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import KFold
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix, classification_report

# %%
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
print(f'GPU: {len(gpus)} device(s)')
print(f'TensorFlow: {tf.__version__}')
# Out:
# GPU: 1 device(s)
# TensorFlow: 2.10.0

# %%
SOURCE_DIR  = 'audio_files_augmented'
META_CSV    = 'metadata_augmented.csv'
CACHE_DIR   = 'feature_cache_mt'
MODEL_PATH  = os.path.join('models', 'cnn_multitask.h5')

SAMPLE_RATE = 22050
SAMPLES     = SAMPLE_RATE * 3
N_MELS      = 128
N_FFT       = 2048
HOP_LENGTH  = 512

EMOTION_NAMES   = ['calm','happy','sad','angry','fearful','disgust','surprised']
INTENSITY_NAMES = ['normal','strong']
GENDER_NAMES    = ['male','female']
NUM_EMO = 7
NUM_INT = 2
NUM_GEN = 2

EMOTION_MAP   = {e: i for i, e in enumerate(EMOTION_NAMES)}
INTENSITY_MAP = {'normal': 0, 'strong': 1}
GENDER_MAP    = {'male': 0, 'female': 1}

print('Emotion classes:', EMOTION_NAMES)
# Out:
# Emotion classes: ['calm', 'happy', 'sad', 'angry', 'fearful', 'disgust', 'surprised']

# %%
def fix_length(y):
    if len(y) > SAMPLES:
        return y[:SAMPLES]
    pad = SAMPLES - len(y)
    return np.pad(y, (pad // 2, pad - pad // 2), 'constant')

def to_3ch(y, sr):
    mel    = librosa.feature.melspectrogram(
                 y=y, sr=sr, n_mels=N_MELS,
                 n_fft=N_FFT, hop_length=HOP_LENGTH, fmax=8000)
    mel_db = librosa.power_to_db(mel, ref=np.max)
    return np.stack([
        mel_db,
        librosa.feature.delta(mel_db),
        librosa.feature.delta(mel_db, order=2)
    ], axis=-1)

def wav_to_feat(path):
    try:
        y, sr = librosa.load(path, sr=SAMPLE_RATE)
        return to_3ch(fix_length(y), sr)
    except Exception as e:
        print(f'  Error: {path} — {e}')
        return None

# %% [markdown]
# ## Step 1 — Extract features from metadata_augmented.csv

# %%
os.makedirs(CACHE_DIR, exist_ok=True)

cache_X   = os.path.join(CACHE_DIR, 'X.npy')
cache_emo = os.path.join(CACHE_DIR, 'y_emotion.npy')
cache_int = os.path.join(CACHE_DIR, 'y_intensity.npy')
cache_gen = os.path.join(CACHE_DIR, 'y_gender.npy')
cache_src = os.path.join(CACHE_DIR, 'sources.npy')

if all(os.path.exists(p) for p in [cache_X, cache_emo, cache_int, cache_gen, cache_src]):
    X_all       = np.load(cache_X)
    y_emotion   = np.load(cache_emo)
    y_intensity = np.load(cache_int)
    y_gender    = np.load(cache_gen)
    sources     = np.load(cache_src)
    print(f'Cache loaded: {X_all.shape}')
else:
    df = pd.read_csv(META_CSV)
    print(f'Total rows in metadata: {len(df)}')

    feats, emos, ints, gens, srcs = [], [], [], [], []
    skipped = 0

    for i, row in df.iterrows():
        fname     = str(row['file_name'])     
        emotion   = str(row['emotion'])
        intensity = str(row['intensity'])
        gender    = str(row['gender'])

        if emotion not in EMOTION_MAP:
            skipped += 1
            continue

        if not fname.endswith('.wav'):
            fname = fname + '.wav'

        fpath = os.path.join(SOURCE_DIR, fname)
        if not os.path.exists(fpath):
            fpath = os.path.join('audio_files', fname)
            if not os.path.exists(fpath):
                skipped += 1
                continue

        feat = wav_to_feat(fpath)
        if feat is None:
            skipped += 1
            continue
        stem = fname.split('__')[0]

        feats.append(feat)
        emos.append(EMOTION_MAP[emotion])
        ints.append(INTENSITY_MAP.get(intensity, 0))
        gens.append(GENDER_MAP.get(gender, 0))
        srcs.append(stem)

        if i % 300 == 0:
            print(f'  {i}/{len(df)} processed...')

    X_all       = np.array(feats, dtype=np.float32)
    y_emotion   = np.array(emos,  dtype=np.int32)
    y_intensity = np.array(ints,  dtype=np.int32)
    y_gender    = np.array(gens,  dtype=np.int32)
    sources     = np.array(srcs)

    np.save(cache_X,   X_all)
    np.save(cache_emo, y_emotion)
    np.save(cache_int, y_intensity)
    np.save(cache_gen, y_gender)
    np.save(cache_src, sources)
    print(f'Cached: {X_all.shape}  skipped: {skipped}')

print(f'\nTotal samples: {len(y_emotion)}')
print('\nEmotion distribution:')
for i, name in enumerate(EMOTION_NAMES):
    print(f'  {name:<10} {(y_emotion==i).sum():>5}')
print(f'\nIntensity — normal: {(y_intensity==0).sum()}  strong: {(y_intensity==1).sum()}')
print(f'Gender    — male:   {(y_gender==0).sum()}     female: {(y_gender==1).sum()}')
# Out:
# Cache loaded: (3360, 128, 130, 3)
#
# Total samples: 3360
#
# Emotion distribution:
#   calm         480
#   happy        480
#   sad          480
#   angry        480
#   fearful      480
#   disgust      480
#   surprised    480
#
# Intensity — normal: 1680  strong: 1680
# Gender    — male:   1680     female: 1680

# %% [markdown]
# ## Step 2 — Multi-task model (shared backbone + 3 heads)

# %%
def focal_loss(gamma=2.0):
    """Manual focal loss — compatible with TF 2.10."""
    def loss_fn(y_true, y_pred):
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0)
        ce     = -y_true * tf.math.log(y_pred)
        weight = y_true * tf.math.pow(1.0 - y_pred, gamma)
        return tf.reduce_mean(tf.reduce_sum(weight * ce, axis=1))
    return loss_fn


def build_multitask_model(input_shape):
    """
    Shared backbone: Conv(32) -> Conv(64) -> Conv(128) -> GAP -> Dense(128)
    Three heads branching from the shared Dense layer:
      - emotion   (7 classes, focal loss, weight=1.0)
      - intensity (2 classes, crossentropy, weight=0.3)
      - gender    (2 classes, crossentropy, weight=0.2)
    Loss weights stop easy tasks (gender ~98%) dominating backbone gradients.
    """
    inp = Input(shape=input_shape)

    x = Conv2D(32, (3,3), activation='relu', padding='same',
               kernel_regularizer=regularizers.l2(0.001))(inp)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2,2))(x)
    x = Dropout(0.25)(x)

    x = Conv2D(64, (3,3), activation='relu', padding='same',
               kernel_regularizer=regularizers.l2(0.001))(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2,2))(x)
    x = Dropout(0.25)(x)

    x = Conv2D(128, (3,3), activation='relu', padding='same',
               kernel_regularizer=regularizers.l2(0.001))(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2,2))(x)
    x = Dropout(0.3)(x)

    shared = GlobalAveragePooling2D()(x)
    shared = Dense(128, activation='relu',
                   kernel_regularizer=regularizers.l2(0.001))(shared)
    shared = Dropout(0.4)(shared)

    # Emotion head — primary task
    h = Dense(64, activation='relu')(shared)
    h = Dropout(0.3)(h)
    out_emotion = Dense(NUM_EMO, activation='softmax', name='emotion')(h)

    # Intensity head — auxiliary
    h = Dense(32, activation='relu')(shared)
    h = Dropout(0.2)(h)
    out_intensity = Dense(NUM_INT, activation='softmax', name='intensity')(h)

    # Gender head — auxiliary
    h = Dense(32, activation='relu')(shared)
    h = Dropout(0.2)(h)
    out_gender = Dense(NUM_GEN, activation='softmax', name='gender')(h)

    model = Model(inputs=inp,
                  outputs=[out_emotion, out_intensity, out_gender])
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss={
            'emotion':   focal_loss(gamma=2.0),
            'intensity': 'categorical_crossentropy',
            'gender':    'categorical_crossentropy',
        },
        loss_weights={'emotion': 1.0, 'intensity': 0.3, 'gender': 0.2},
        metrics={
            'emotion':   'accuracy',
            'intensity': 'accuracy',
            'gender':    'accuracy',
        }
    )
    return model

# Sanity check
_m = build_multitask_model((128, 130, 3))
_m.summary()
del _m
tf.keras.backend.clear_session()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 130, 3  0           []
#                                 )]
#
#  conv2d_3 (Conv2D)              (None, 128, 130, 32  896         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 128, 130, 32  128        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 64, 65, 32)  0           ['batch_normalization_3[0][0]']
#
#  dropout_7 (Dropout)            (None, 64, 65, 32)   0           ['max_pooling2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 65, 64)   18496       ['dropout_7[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 65, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 64)  0           ['batch_normalization_4[0][0]']
#
#  dropout_8 (Dropout)            (None, 32, 32, 64)   0           ['max_pooling2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 128)  73856       ['dropout_8[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 128)  0          ['batch_normalization_5[0][0]']
#
#  dropout_9 (Dropout)            (None, 16, 16, 128)  0           ['max_pooling2d_5[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 128)         0           ['dropout_9[0][0]']
#  obalAveragePooling2D)
#
#  dense_4 (Dense)                (None, 128)          16512       ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dropout_10 (Dropout)           (None, 128)          0           ['dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 64)           8256        ['dropout_10[0][0]']
#
#  dense_6 (Dense)                (None, 32)           4128        ['dropout_10[0][0]']
#
#  dense_7 (Dense)                (None, 32)           4128        ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)           (None, 64)           0           ['dense_5[0][0]']
#
#  dropout_12 (Dropout)           (None, 32)           0           ['dense_6[0][0]']
#
#  dropout_13 (Dropout)           (None, 32)           0           ['dense_7[0][0]']
#
#  emotion (Dense)                (None, 7)            455         ['dropout_11[0][0]']
#
#  intensity (Dense)              (None, 2)            66          ['dropout_12[0][0]']
#
#  gender (Dense)                 (None, 2)            66          ['dropout_13[0][0]']
#
# ==================================================================================================
# Total params: 127,755
# Trainable params: 127,307
# Non-trainable params: 448
# __________________________________________________________________________________________________

# %% [markdown]
# ## Step 3 — Training (5-fold, leakage-proof split on original stems)

# %%
BATCH_SIZE = 64

def make_dataset_mt(X, y_emo, y_int, y_gen, shuffle=False):
    ds = tf.data.Dataset.from_tensor_slices((
        X,
        {'emotion': y_emo, 'intensity': y_int, 'gender': y_gen}
    ))
    if shuffle:
        ds = ds.shuffle(buffer_size=len(X), reshuffle_each_iteration=True)
    return ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)


unique_sources = np.unique(sources)
kfold          = KFold(n_splits=5, shuffle=True, random_state=42)
fold_results   = []

for fold, (tr_src_idx, va_src_idx) in enumerate(kfold.split(unique_sources)):
    print(f'\n── Fold {fold+1}/5 ──')

    tr_stems = set(unique_sources[tr_src_idx])
    va_stems = set(unique_sources[va_src_idx])

    tr_mask = np.array([s in tr_stems for s in sources])
    va_mask = np.array([s in va_stems for s in sources])

    X_tr = X_all[tr_mask].astype(np.float32)
    X_va = X_all[va_mask].astype(np.float32)

    ye_tr = y_emotion[tr_mask];   ye_va = y_emotion[va_mask]
    yi_tr = y_intensity[tr_mask]; yi_va = y_intensity[va_mask]
    yg_tr = y_gender[tr_mask];    yg_va = y_gender[va_mask]

    train_ds = make_dataset_mt(
        X_tr,
        to_categorical(ye_tr, NUM_EMO),
        to_categorical(yi_tr, NUM_INT),
        to_categorical(yg_tr, NUM_GEN),
        shuffle=True
    )
    val_ds = make_dataset_mt(
        X_va,
        to_categorical(ye_va, NUM_EMO),
        to_categorical(yi_va, NUM_INT),
        to_categorical(yg_va, NUM_GEN),
    )

    print(f'  Train: {len(X_tr)}  Val: {len(X_va)}')

    tf.keras.backend.clear_session()
    model = build_multitask_model(X_tr.shape[1:])

    callbacks = [
        ReduceLROnPlateau(monitor='val_emotion_accuracy',
                          patience=7, factor=0.5, min_lr=1e-5, verbose=0),
        EarlyStopping(monitor='val_emotion_accuracy',
                      patience=20, restore_best_weights=True)
    ]

    model.fit(
        train_ds,
        epochs=120,
        validation_data=val_ds,
        callbacks=callbacks,
        verbose=1
    )

    preds    = model.predict(val_ds, verbose=0)
    pred_emo = np.argmax(preds[0], axis=1)
    pred_int = np.argmax(preds[1], axis=1)
    pred_gen = np.argmax(preds[2], axis=1)

    acc_emo = np.mean(pred_emo == ye_va)
    acc_int = np.mean(pred_int == yi_va)
    acc_gen = np.mean(pred_gen == yg_va)

    fold_results.append({
        'fold': fold+1, 'model': model,
        'acc_emo': acc_emo, 'acc_int': acc_int, 'acc_gen': acc_gen,
        'pred_emo': pred_emo, 'true_emo': ye_va,
        'pred_int': pred_int, 'true_int': yi_va,
        'pred_gen': pred_gen, 'true_gen': yg_va,
    })
    print(f'  emotion={acc_emo:.4f}  intensity={acc_int:.4f}  gender={acc_gen:.4f}')

best  = max(fold_results, key=lambda x: x['acc_emo'])
model = best['model']
print(f'\nEmotion   mean={np.mean([r["acc_emo"] for r in fold_results]):.4f}')
print(f'Intensity mean={np.mean([r["acc_int"] for r in fold_results]):.4f}')
print(f'Gender    mean={np.mean([r["acc_gen"] for r in fold_results]):.4f}')
print(f'Best fold: {best["fold"]}')
# Out:
# ── Fold 1/5 ──
#   Train: 2692  Val: 668
# Epoch 1/120
# 43/43 [==============================] - 5s 72ms/step - loss: 2.0607 - emotion_loss: 1.4542 - intensity_loss: 0.7036 - gender_loss: 0.7154 - emotion_accuracy: 0.1802 - intensity_accuracy: 0.5360 - gender_accuracy: 0.5334 - val_loss: 2.2289 - val_emotion_loss: 1.6378 - val_intensity_loss: 0.6951 - val_gender_loss: 0.6943 - val_emotion_accuracy: 0.1632 - val_intensity_accuracy: 0.5000 - val_gender_accuracy: 0.5344 - lr: 0.0010
# Epoch 2/120
# 43/43 [==============================] - 3s 60ms/step - loss: 1.8733 - emotion_loss: 1.2978 - intensity_loss: 0.6832 - gender_loss: 0.6699 - emotion_accuracy: 0.2467 - intensity_accuracy: 0.5539 - gender_accuracy: 0.5914 - val_loss: 1.9789 - val_emotion_loss: 1.4076 - val_intensity_loss: 0.6945 - val_gender_loss: 0.6688 - val_emotion_accuracy: 0.1737 - val_intensity_accuracy: 0.5195 - val_gender_accuracy: 0.6452 - lr: 0.0010
# Epoch 3/120
# 43/43 [==============================] - 3s 61ms/step - loss: 1.7088 - emotion_loss: 1.1596 - intensity_loss: 0.6661 - gender_loss: 0.6299 - emotion_accuracy: 0.3076 - intensity_accuracy: 0.6163 - gender_accuracy: 0.6441 - val_loss: 2.2091 - val_emotion_loss: 1.5733 - val_intensity_loss: 0.7569 - val_gender_loss: 0.9587 - val_emotion_accuracy: 0.1901 - val_intensity_accuracy: 0.5000 - val_gender_accuracy: 0.5344 - lr: 0.0010
# Epoch 4/120
# 43/43 [==============================] - 3s 60ms/step - loss: 1.6074 - emotion_loss: 1.0898 - intensity_loss: 0.6469 - gender_loss: 0.5579 - emotion_accuracy: 0.3447 - intensity_accuracy: 0.6304 - gender_accuracy: 0.7270 - val_loss: 2.1331 - val_emotion_loss: 1.5475 - val_intensity_loss: 0.7325 - val_gender_loss: 0.7977 - val_emotion_accuracy: 0.1422 - val_intensity_accuracy: 0.5000 - val_gender_accuracy: 0.4775 - lr: 0.0010
# Epoch 5/120
# 43/43 [==============================] - 3s 60ms/step - loss: 1.5469 - emotion_loss: 1.0506 - intensity_loss: 0.6329 - gender_loss: 0.5185 - emotion_accuracy: 0.3789 - intensity_accuracy: 0.6438 - gender_accuracy: 0.7522 - val_loss: 2.0555 - val_emotion_loss: 1.4060 - val_intensity_loss: 0.6786 - val_gender_loss: 1.2378 - val_emotion_accuracy: 0.2275 - val_intensity_accuracy: 0.5299 - val_gender_accuracy: 0.4656 - lr: 0.0010
# Epoch 6/120
# 43/43 [==============================] - 3s 60ms/step - loss: 1.4346 - emotion_loss: 0.9582 - intensity_loss: 0.6259 - gender_loss: 0.4681 - emotion_accuracy: 0.4268 - intensity_accuracy: 0.6519 - gender_accuracy: 0.7779 - val_loss: 2.1597 - val_emotion_loss: 1.6126 - val_intensity_loss: 0.7461 - val_gender_loss: 0.6610 - val_emotion_accuracy: 0.1557 - val_intensity_accuracy: 0.5000 - val_gender_accuracy: 0.5659 - lr: 0.0010
# Epoch 7/120
# 43/43 [==============================] - 3s 64ms/step - loss: 1.3633 - emotion_loss: 0.9063 - intensity_loss: 0.6105 - gender_loss: 0.4302 - emotion_accuracy: 0.4421 - intensity_accuracy: 0.6709 - gender_accuracy: 0.7961 - val_loss: 2.8749 - val_emotion_loss: 2.2634 - val_intensity_loss: 0.8677 - val_gender_loss: 0.8339 - val_emotion_accuracy: 0.2380 - val_intensity_accuracy: 0.5000 - val_gender_accuracy: 0.4716 - lr: 0.0010
# Epoch 8/120
# 43/43 [==============================] - 3s 61ms/step - loss: 1.3094 - emotion_loss: 0.8629 - intensity_loss: 0.6104 - gender_loss: 0.4038 - emotion_accuracy: 0.4703 - intensity_accuracy: 0.6642 - gender_accuracy: 0.8172 - val_loss: 2.2699 - val_emotion_loss: 1.6711 - val_intensity_loss: 0.8658 - val_gender_loss: 0.7941 - val_emotion_accuracy: 0.1931 - val_intensity_accuracy: 0.5000 - val_gender_accuracy: 0.4880 - lr: 0.0010
# Epoch 9/120
# 43/43 [==============================] - 3s 61ms/step - loss: 1.2199 - emotion_loss: 0.7960 - intensity_loss: 0.5946 - gender_loss: 0.3382 - emotion_accuracy: 0.5033 - intensity_accuracy: 0.6798 - gender_accuracy: 0.8540 - val_loss: 2.1249 - val_emotion_loss: 1.5634 - val_intensity_loss: 0.9038 - val_gender_loss: 0.5741 - val_emotion_accuracy: 0.2126 - val_intensity_accuracy: 0.5000 - val_gender_accuracy: 0.6617 - lr: 0.0010
# Epoch 10/120
# 43/43 [==============================] - 3s 61ms/step - loss: 1.2048 - emotion_loss: 0.7888 - intensity_loss: 0.5900 - gender_loss: 0.3222 - emotion_accuracy: 0.4922 - intensity_accuracy: 0.6876 - gender_accuracy: 0.8540 - val_loss: 1.6009 - val_emotion_loss: 1.1033 - val_intensity_loss: 0.7014 - val_gender_loss: 0.5694 - val_emotion_accuracy: 0.3234 - val_intensity_accuracy: 0.5569 - val_gender_accuracy: 0.6407 - lr: 0.0010
# Epoch 11/120
# 43/43 [==============================] - 3s 61ms/step - loss: 1.1011 - emotion_loss: 0.6982 - intensity_loss: 0.5820 - gender_loss: 0.2780 - emotion_accuracy: 0.5397 - intensity_accuracy: 0.6898 - gender_accuracy: 0.8871 - val_loss: 2.1533 - val_emotion_loss: 1.6600 - val_intensity_loss: 0.7608 - val_gender_loss: 0.4673 - val_emotion_accuracy: 0.2126 - val_intensity_accuracy: 0.5075 - val_gender_accuracy: 0.7380 - lr: 0.0010
# Epoch 12/120
# 43/43 [==============================] - 3s 61ms/step - loss: 1.0632 - emotion_loss: 0.6607 - intensity_loss: 0.5919 - gender_loss: 0.2678 - emotion_accuracy: 0.5594 - intensity_accuracy: 0.6831 - gender_accuracy: 0.8882 - val_loss: 3.7872 - val_emotion_loss: 2.9374 - val_intensity_loss: 1.3725 - val_gender_loss: 1.3353 - val_emotion_accuracy: 0.1377 - val_intensity_accuracy: 0.4970 - val_gender_accuracy: 0.4746 - lr: 0.0010
# Epoch 13/120
# 43/43 [==============================] - 3s 61ms/step - loss: 1.0514 - emotion_loss: 0.6474 - intensity_loss: 0.5859 - gender_loss: 0.2845 - emotion_accuracy: 0.5739 - intensity_accuracy: 0.6839 - gender_accuracy: 0.8763 - val_loss: 1.4302 - val_emotion_loss: 0.9848 - val_intensity_loss: 0.6227 - val_gender_loss: 0.4367 - val_emotion_accuracy: 0.4117 - val_intensity_accuracy: 0.6707 - val_gender_accuracy: 0.7620 - lr: 0.0010
# Epoch 14/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.9658 - emotion_loss: 0.5760 - intensity_loss: 0.5703 - gender_loss: 0.2390 - emotion_accuracy: 0.6059 - intensity_accuracy: 0.7047 - gender_accuracy: 0.9012 - val_loss: 2.1209 - val_emotion_loss: 1.5495 - val_intensity_loss: 0.7658 - val_gender_loss: 0.8555 - val_emotion_accuracy: 0.2844 - val_intensity_accuracy: 0.5419 - val_gender_accuracy: 0.5240 - lr: 0.0010
# Epoch 15/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.9541 - emotion_loss: 0.5627 - intensity_loss: 0.5714 - gender_loss: 0.2407 - emotion_accuracy: 0.6185 - intensity_accuracy: 0.7051 - gender_accuracy: 0.8997 - val_loss: 6.0809 - val_emotion_loss: 5.5688 - val_intensity_loss: 0.8722 - val_gender_loss: 0.3924 - val_emotion_accuracy: 0.1347 - val_intensity_accuracy: 0.5030 - val_gender_accuracy: 0.8278 - lr: 0.0010
# Epoch 16/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.9024 - emotion_loss: 0.5140 - intensity_loss: 0.5614 - gender_loss: 0.2356 - emotion_accuracy: 0.6300 - intensity_accuracy: 0.7088 - gender_accuracy: 0.8949 - val_loss: 1.6193 - val_emotion_loss: 1.0640 - val_intensity_loss: 0.8128 - val_gender_loss: 0.6924 - val_emotion_accuracy: 0.4117 - val_intensity_accuracy: 0.5165 - val_gender_accuracy: 0.6722 - lr: 0.0010
# Epoch 17/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.8852 - emotion_loss: 0.4954 - intensity_loss: 0.5611 - gender_loss: 0.2335 - emotion_accuracy: 0.6516 - intensity_accuracy: 0.7099 - gender_accuracy: 0.9030 - val_loss: 1.2773 - val_emotion_loss: 0.8641 - val_intensity_loss: 0.6274 - val_gender_loss: 0.2477 - val_emotion_accuracy: 0.4566 - val_intensity_accuracy: 0.6632 - val_gender_accuracy: 0.8967 - lr: 0.0010
# Epoch 18/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.8151 - emotion_loss: 0.4332 - intensity_loss: 0.5450 - gender_loss: 0.2155 - emotion_accuracy: 0.6709 - intensity_accuracy: 0.7292 - gender_accuracy: 0.9142 - val_loss: 2.0715 - val_emotion_loss: 1.6722 - val_intensity_loss: 0.5989 - val_gender_loss: 0.2220 - val_emotion_accuracy: 0.2740 - val_intensity_accuracy: 0.6692 - val_gender_accuracy: 0.8997 - lr: 0.0010
# Epoch 19/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.8309 - emotion_loss: 0.4480 - intensity_loss: 0.5466 - gender_loss: 0.2084 - emotion_accuracy: 0.6683 - intensity_accuracy: 0.7247 - gender_accuracy: 0.9172 - val_loss: 2.0678 - val_emotion_loss: 1.5019 - val_intensity_loss: 0.6483 - val_gender_loss: 0.9681 - val_emotion_accuracy: 0.3847 - val_intensity_accuracy: 0.5868 - val_gender_accuracy: 0.6991 - lr: 0.0010
# Epoch 20/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.7772 - emotion_loss: 0.3932 - intensity_loss: 0.5467 - gender_loss: 0.2059 - emotion_accuracy: 0.6880 - intensity_accuracy: 0.7166 - gender_accuracy: 0.9175 - val_loss: 1.4025 - val_emotion_loss: 0.9965 - val_intensity_loss: 0.5929 - val_gender_loss: 0.2430 - val_emotion_accuracy: 0.4566 - val_intensity_accuracy: 0.7096 - val_gender_accuracy: 0.9177 - lr: 0.0010
# Epoch 21/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.7584 - emotion_loss: 0.3738 - intensity_loss: 0.5350 - gender_loss: 0.2161 - emotion_accuracy: 0.7077 - intensity_accuracy: 0.7169 - gender_accuracy: 0.9064 - val_loss: 1.4644 - val_emotion_loss: 1.0005 - val_intensity_loss: 0.6143 - val_gender_loss: 0.4906 - val_emotion_accuracy: 0.4581 - val_intensity_accuracy: 0.6422 - val_gender_accuracy: 0.8129 - lr: 0.0010
# Epoch 22/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.7900 - emotion_loss: 0.4054 - intensity_loss: 0.5321 - gender_loss: 0.2020 - emotion_accuracy: 0.6932 - intensity_accuracy: 0.7255 - gender_accuracy: 0.9160 - val_loss: 1.4255 - val_emotion_loss: 1.0236 - val_intensity_loss: 0.5558 - val_gender_loss: 0.2460 - val_emotion_accuracy: 0.4162 - val_intensity_accuracy: 0.6871 - val_gender_accuracy: 0.9072 - lr: 0.0010
# Epoch 23/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.7053 - emotion_loss: 0.3257 - intensity_loss: 0.5276 - gender_loss: 0.1730 - emotion_accuracy: 0.7496 - intensity_accuracy: 0.7337 - gender_accuracy: 0.9320 - val_loss: 1.4208 - val_emotion_loss: 1.0156 - val_intensity_loss: 0.5824 - val_gender_loss: 0.2188 - val_emotion_accuracy: 0.4566 - val_intensity_accuracy: 0.6991 - val_gender_accuracy: 0.9177 - lr: 0.0010
# Epoch 24/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.6745 - emotion_loss: 0.2982 - intensity_loss: 0.5211 - gender_loss: 0.1655 - emotion_accuracy: 0.7545 - intensity_accuracy: 0.7377 - gender_accuracy: 0.9365 - val_loss: 1.1285 - val_emotion_loss: 0.7293 - val_intensity_loss: 0.5289 - val_gender_loss: 0.2689 - val_emotion_accuracy: 0.5180 - val_intensity_accuracy: 0.7380 - val_gender_accuracy: 0.8578 - lr: 0.0010
# Epoch 25/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.7259 - emotion_loss: 0.3493 - intensity_loss: 0.5131 - gender_loss: 0.1652 - emotion_accuracy: 0.7285 - intensity_accuracy: 0.7389 - gender_accuracy: 0.9357 - val_loss: 2.3890 - val_emotion_loss: 1.9728 - val_intensity_loss: 0.5858 - val_gender_loss: 0.2461 - val_emotion_accuracy: 0.3293 - val_intensity_accuracy: 0.6871 - val_gender_accuracy: 0.8997 - lr: 0.0010
# Epoch 26/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.6747 - emotion_loss: 0.2984 - intensity_loss: 0.5066 - gender_loss: 0.1590 - emotion_accuracy: 0.7578 - intensity_accuracy: 0.7448 - gender_accuracy: 0.9357 - val_loss: 2.2686 - val_emotion_loss: 1.7539 - val_intensity_loss: 0.8696 - val_gender_loss: 0.3053 - val_emotion_accuracy: 0.3039 - val_intensity_accuracy: 0.5449 - val_gender_accuracy: 0.8578 - lr: 0.0010
# Epoch 27/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.6325 - emotion_loss: 0.2618 - intensity_loss: 0.4926 - gender_loss: 0.1494 - emotion_accuracy: 0.7849 - intensity_accuracy: 0.7574 - gender_accuracy: 0.9361 - val_loss: 1.5425 - val_emotion_loss: 1.1423 - val_intensity_loss: 0.5846 - val_gender_loss: 0.1587 - val_emotion_accuracy: 0.4731 - val_intensity_accuracy: 0.6737 - val_gender_accuracy: 0.9371 - lr: 0.0010
# Epoch 28/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.6484 - emotion_loss: 0.2825 - intensity_loss: 0.4818 - gender_loss: 0.1382 - emotion_accuracy: 0.7756 - intensity_accuracy: 0.7660 - gender_accuracy: 0.9495 - val_loss: 2.0840 - val_emotion_loss: 1.6580 - val_intensity_loss: 0.5670 - val_gender_loss: 0.3088 - val_emotion_accuracy: 0.3892 - val_intensity_accuracy: 0.6946 - val_gender_accuracy: 0.9027 - lr: 0.0010
# Epoch 29/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.6474 - emotion_loss: 0.2812 - intensity_loss: 0.4703 - gender_loss: 0.1433 - emotion_accuracy: 0.7805 - intensity_accuracy: 0.7868 - gender_accuracy: 0.9450 - val_loss: 1.6160 - val_emotion_loss: 0.9830 - val_intensity_loss: 0.5451 - val_gender_loss: 1.3611 - val_emotion_accuracy: 0.4970 - val_intensity_accuracy: 0.7081 - val_gender_accuracy: 0.5943 - lr: 0.0010
# Epoch 30/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.6472 - emotion_loss: 0.2740 - intensity_loss: 0.4769 - gender_loss: 0.1537 - emotion_accuracy: 0.7812 - intensity_accuracy: 0.7756 - gender_accuracy: 0.9302 - val_loss: 1.3575 - val_emotion_loss: 0.9386 - val_intensity_loss: 0.5866 - val_gender_loss: 0.2139 - val_emotion_accuracy: 0.4401 - val_intensity_accuracy: 0.6722 - val_gender_accuracy: 0.9177 - lr: 0.0010
# Epoch 31/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.5733 - emotion_loss: 0.2116 - intensity_loss: 0.4605 - gender_loss: 0.1190 - emotion_accuracy: 0.8180 - intensity_accuracy: 0.7775 - gender_accuracy: 0.9517 - val_loss: 1.8385 - val_emotion_loss: 1.4101 - val_intensity_loss: 0.6056 - val_gender_loss: 0.2387 - val_emotion_accuracy: 0.3802 - val_intensity_accuracy: 0.6497 - val_gender_accuracy: 0.9057 - lr: 0.0010
# Epoch 32/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.5330 - emotion_loss: 0.1782 - intensity_loss: 0.4471 - gender_loss: 0.1115 - emotion_accuracy: 0.8436 - intensity_accuracy: 0.7871 - gender_accuracy: 0.9591 - val_loss: 1.3244 - val_emotion_loss: 0.9180 - val_intensity_loss: 0.5821 - val_gender_loss: 0.1716 - val_emotion_accuracy: 0.5045 - val_intensity_accuracy: 0.6946 - val_gender_accuracy: 0.9207 - lr: 5.0000e-04
# Epoch 33/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.5471 - emotion_loss: 0.1889 - intensity_loss: 0.4453 - gender_loss: 0.1360 - emotion_accuracy: 0.8347 - intensity_accuracy: 0.7905 - gender_accuracy: 0.9510 - val_loss: 1.0375 - val_emotion_loss: 0.6549 - val_intensity_loss: 0.5072 - val_gender_loss: 0.1677 - val_emotion_accuracy: 0.6332 - val_intensity_accuracy: 0.7395 - val_gender_accuracy: 0.9416 - lr: 5.0000e-04
# Epoch 34/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.5238 - emotion_loss: 0.1711 - intensity_loss: 0.4371 - gender_loss: 0.1253 - emotion_accuracy: 0.8522 - intensity_accuracy: 0.8016 - gender_accuracy: 0.9521 - val_loss: 1.1014 - val_emotion_loss: 0.7236 - val_intensity_loss: 0.5000 - val_gender_loss: 0.1595 - val_emotion_accuracy: 0.6003 - val_intensity_accuracy: 0.7395 - val_gender_accuracy: 0.9401 - lr: 5.0000e-04
# Epoch 35/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.5301 - emotion_loss: 0.1838 - intensity_loss: 0.4263 - gender_loss: 0.1131 - emotion_accuracy: 0.8488 - intensity_accuracy: 0.8061 - gender_accuracy: 0.9551 - val_loss: 1.0403 - val_emotion_loss: 0.6601 - val_intensity_loss: 0.4874 - val_gender_loss: 0.1931 - val_emotion_accuracy: 0.5853 - val_intensity_accuracy: 0.7874 - val_gender_accuracy: 0.9251 - lr: 5.0000e-04
# Epoch 36/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.5252 - emotion_loss: 0.1798 - intensity_loss: 0.4198 - gender_loss: 0.1193 - emotion_accuracy: 0.8496 - intensity_accuracy: 0.8020 - gender_accuracy: 0.9543 - val_loss: 0.9911 - val_emotion_loss: 0.5889 - val_intensity_loss: 0.5018 - val_gender_loss: 0.2816 - val_emotion_accuracy: 0.6512 - val_intensity_accuracy: 0.7410 - val_gender_accuracy: 0.8967 - lr: 5.0000e-04
# Epoch 37/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.4907 - emotion_loss: 0.1496 - intensity_loss: 0.4113 - gender_loss: 0.1143 - emotion_accuracy: 0.8685 - intensity_accuracy: 0.8139 - gender_accuracy: 0.9536 - val_loss: 0.8216 - val_emotion_loss: 0.4452 - val_intensity_loss: 0.4863 - val_gender_loss: 0.1814 - val_emotion_accuracy: 0.6856 - val_intensity_accuracy: 0.7620 - val_gender_accuracy: 0.9207 - lr: 5.0000e-04
# Epoch 38/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.4705 - emotion_loss: 0.1391 - intensity_loss: 0.3981 - gender_loss: 0.0923 - emotion_accuracy: 0.8756 - intensity_accuracy: 0.8217 - gender_accuracy: 0.9629 - val_loss: 1.7217 - val_emotion_loss: 1.2845 - val_intensity_loss: 0.6364 - val_gender_loss: 0.2672 - val_emotion_accuracy: 0.4910 - val_intensity_accuracy: 0.6542 - val_gender_accuracy: 0.9072 - lr: 5.0000e-04
# Epoch 39/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.5441 - emotion_loss: 0.2027 - intensity_loss: 0.4165 - gender_loss: 0.1137 - emotion_accuracy: 0.8332 - intensity_accuracy: 0.8072 - gender_accuracy: 0.9547 - val_loss: 0.9688 - val_emotion_loss: 0.5873 - val_intensity_loss: 0.5200 - val_gender_loss: 0.1577 - val_emotion_accuracy: 0.6272 - val_intensity_accuracy: 0.7260 - val_gender_accuracy: 0.9431 - lr: 5.0000e-04
# Epoch 40/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.4893 - emotion_loss: 0.1551 - intensity_loss: 0.3961 - gender_loss: 0.1063 - emotion_accuracy: 0.8633 - intensity_accuracy: 0.8265 - gender_accuracy: 0.9577 - val_loss: 1.0882 - val_emotion_loss: 0.6325 - val_intensity_loss: 0.5416 - val_gender_loss: 0.4975 - val_emotion_accuracy: 0.6243 - val_intensity_accuracy: 0.7021 - val_gender_accuracy: 0.8428 - lr: 5.0000e-04
# Epoch 41/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.4868 - emotion_loss: 0.1470 - intensity_loss: 0.4147 - gender_loss: 0.1072 - emotion_accuracy: 0.8674 - intensity_accuracy: 0.8079 - gender_accuracy: 0.9606 - val_loss: 1.3408 - val_emotion_loss: 0.8799 - val_intensity_loss: 0.5885 - val_gender_loss: 0.4542 - val_emotion_accuracy: 0.5539 - val_intensity_accuracy: 0.6602 - val_gender_accuracy: 0.8593 - lr: 5.0000e-04
# Epoch 42/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.4450 - emotion_loss: 0.1207 - intensity_loss: 0.3792 - gender_loss: 0.0869 - emotion_accuracy: 0.8867 - intensity_accuracy: 0.8362 - gender_accuracy: 0.9692 - val_loss: 0.9737 - val_emotion_loss: 0.5647 - val_intensity_loss: 0.5291 - val_gender_loss: 0.2890 - val_emotion_accuracy: 0.6677 - val_intensity_accuracy: 0.7290 - val_gender_accuracy: 0.9012 - lr: 5.0000e-04
# Epoch 43/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.4486 - emotion_loss: 0.1268 - intensity_loss: 0.3668 - gender_loss: 0.0995 - emotion_accuracy: 0.8845 - intensity_accuracy: 0.8340 - gender_accuracy: 0.9606 - val_loss: 0.8901 - val_emotion_loss: 0.5116 - val_intensity_loss: 0.5128 - val_gender_loss: 0.1674 - val_emotion_accuracy: 0.6886 - val_intensity_accuracy: 0.7605 - val_gender_accuracy: 0.9356 - lr: 5.0000e-04
# Epoch 44/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.4559 - emotion_loss: 0.1377 - intensity_loss: 0.3672 - gender_loss: 0.0853 - emotion_accuracy: 0.8767 - intensity_accuracy: 0.8362 - gender_accuracy: 0.9699 - val_loss: 1.0616 - val_emotion_loss: 0.6383 - val_intensity_loss: 0.6251 - val_gender_loss: 0.2261 - val_emotion_accuracy: 0.6557 - val_intensity_accuracy: 0.7410 - val_gender_accuracy: 0.9237 - lr: 5.0000e-04
# Epoch 45/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.4217 - emotion_loss: 0.1131 - intensity_loss: 0.3406 - gender_loss: 0.0824 - emotion_accuracy: 0.8960 - intensity_accuracy: 0.8548 - gender_accuracy: 0.9692 - val_loss: 1.6273 - val_emotion_loss: 1.2235 - val_intensity_loss: 0.5993 - val_gender_loss: 0.1735 - val_emotion_accuracy: 0.4955 - val_intensity_accuracy: 0.7111 - val_gender_accuracy: 0.9386 - lr: 5.0000e-04
# Epoch 46/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.4274 - emotion_loss: 0.1190 - intensity_loss: 0.3444 - gender_loss: 0.0826 - emotion_accuracy: 0.8993 - intensity_accuracy: 0.8499 - gender_accuracy: 0.9669 - val_loss: 1.3014 - val_emotion_loss: 0.9203 - val_intensity_loss: 0.4700 - val_gender_loss: 0.2610 - val_emotion_accuracy: 0.5808 - val_intensity_accuracy: 0.7769 - val_gender_accuracy: 0.8982 - lr: 5.0000e-04
# Epoch 47/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.4827 - emotion_loss: 0.1717 - intensity_loss: 0.3480 - gender_loss: 0.0878 - emotion_accuracy: 0.8600 - intensity_accuracy: 0.8447 - gender_accuracy: 0.9681 - val_loss: 1.0931 - val_emotion_loss: 0.6473 - val_intensity_loss: 0.7413 - val_gender_loss: 0.1704 - val_emotion_accuracy: 0.6063 - val_intensity_accuracy: 0.7006 - val_gender_accuracy: 0.9341 - lr: 5.0000e-04
# Epoch 48/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.4240 - emotion_loss: 0.1201 - intensity_loss: 0.3316 - gender_loss: 0.0766 - emotion_accuracy: 0.9060 - intensity_accuracy: 0.8611 - gender_accuracy: 0.9695 - val_loss: 1.1281 - val_emotion_loss: 0.7053 - val_intensity_loss: 0.5436 - val_gender_loss: 0.3557 - val_emotion_accuracy: 0.6287 - val_intensity_accuracy: 0.6976 - val_gender_accuracy: 0.8892 - lr: 5.0000e-04
# Epoch 49/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.4545 - emotion_loss: 0.1418 - intensity_loss: 0.3560 - gender_loss: 0.0852 - emotion_accuracy: 0.8841 - intensity_accuracy: 0.8369 - gender_accuracy: 0.9681 - val_loss: 1.4933 - val_emotion_loss: 1.0848 - val_intensity_loss: 0.6046 - val_gender_loss: 0.1914 - val_emotion_accuracy: 0.5225 - val_intensity_accuracy: 0.6916 - val_gender_accuracy: 0.9356 - lr: 5.0000e-04
# Epoch 50/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.4245 - emotion_loss: 0.1206 - intensity_loss: 0.3287 - gender_loss: 0.0827 - emotion_accuracy: 0.8871 - intensity_accuracy: 0.8555 - gender_accuracy: 0.9718 - val_loss: 1.1231 - val_emotion_loss: 0.7363 - val_intensity_loss: 0.5548 - val_gender_loss: 0.1607 - val_emotion_accuracy: 0.6257 - val_intensity_accuracy: 0.6931 - val_gender_accuracy: 0.9461 - lr: 5.0000e-04
# Epoch 51/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.3975 - emotion_loss: 0.1022 - intensity_loss: 0.3057 - gender_loss: 0.0787 - emotion_accuracy: 0.9030 - intensity_accuracy: 0.8785 - gender_accuracy: 0.9725 - val_loss: 0.9405 - val_emotion_loss: 0.5693 - val_intensity_loss: 0.5003 - val_gender_loss: 0.1680 - val_emotion_accuracy: 0.6602 - val_intensity_accuracy: 0.7500 - val_gender_accuracy: 0.9431 - lr: 2.5000e-04
# Epoch 52/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.3890 - emotion_loss: 0.0944 - intensity_loss: 0.3067 - gender_loss: 0.0770 - emotion_accuracy: 0.9138 - intensity_accuracy: 0.8585 - gender_accuracy: 0.9714 - val_loss: 0.8130 - val_emotion_loss: 0.4444 - val_intensity_loss: 0.5044 - val_gender_loss: 0.1525 - val_emotion_accuracy: 0.7156 - val_intensity_accuracy: 0.7635 - val_gender_accuracy: 0.9521 - lr: 2.5000e-04
# Epoch 53/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.3801 - emotion_loss: 0.0886 - intensity_loss: 0.2974 - gender_loss: 0.0791 - emotion_accuracy: 0.9257 - intensity_accuracy: 0.8770 - gender_accuracy: 0.9699 - val_loss: 0.8237 - val_emotion_loss: 0.4144 - val_intensity_loss: 0.6150 - val_gender_loss: 0.1931 - val_emotion_accuracy: 0.7650 - val_intensity_accuracy: 0.7485 - val_gender_accuracy: 0.9326 - lr: 2.5000e-04
# Epoch 54/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.3794 - emotion_loss: 0.0881 - intensity_loss: 0.3024 - gender_loss: 0.0737 - emotion_accuracy: 0.9168 - intensity_accuracy: 0.8711 - gender_accuracy: 0.9721 - val_loss: 0.8270 - val_emotion_loss: 0.4820 - val_intensity_loss: 0.4428 - val_gender_loss: 0.1331 - val_emotion_accuracy: 0.7171 - val_intensity_accuracy: 0.7844 - val_gender_accuracy: 0.9536 - lr: 2.5000e-04
# Epoch 55/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.4124 - emotion_loss: 0.1224 - intensity_loss: 0.3031 - gender_loss: 0.0675 - emotion_accuracy: 0.8897 - intensity_accuracy: 0.8696 - gender_accuracy: 0.9703 - val_loss: 0.7641 - val_emotion_loss: 0.3886 - val_intensity_loss: 0.5234 - val_gender_loss: 0.1650 - val_emotion_accuracy: 0.7500 - val_intensity_accuracy: 0.7410 - val_gender_accuracy: 0.9431 - lr: 2.5000e-04
# Epoch 56/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.3643 - emotion_loss: 0.0821 - intensity_loss: 0.2782 - gender_loss: 0.0678 - emotion_accuracy: 0.9224 - intensity_accuracy: 0.8897 - gender_accuracy: 0.9733 - val_loss: 0.7731 - val_emotion_loss: 0.4055 - val_intensity_loss: 0.5097 - val_gender_loss: 0.1498 - val_emotion_accuracy: 0.7605 - val_intensity_accuracy: 0.7635 - val_gender_accuracy: 0.9536 - lr: 2.5000e-04
# Epoch 57/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.3581 - emotion_loss: 0.0820 - intensity_loss: 0.2591 - gender_loss: 0.0699 - emotion_accuracy: 0.9179 - intensity_accuracy: 0.9001 - gender_accuracy: 0.9744 - val_loss: 0.7203 - val_emotion_loss: 0.3644 - val_intensity_loss: 0.4262 - val_gender_loss: 0.2204 - val_emotion_accuracy: 0.7814 - val_intensity_accuracy: 0.7994 - val_gender_accuracy: 0.9281 - lr: 2.5000e-04
# Epoch 58/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.3688 - emotion_loss: 0.0920 - intensity_loss: 0.2609 - gender_loss: 0.0748 - emotion_accuracy: 0.9183 - intensity_accuracy: 0.8897 - gender_accuracy: 0.9751 - val_loss: 0.7943 - val_emotion_loss: 0.4374 - val_intensity_loss: 0.4325 - val_gender_loss: 0.2196 - val_emotion_accuracy: 0.7350 - val_intensity_accuracy: 0.8159 - val_gender_accuracy: 0.9341 - lr: 2.5000e-04
# Epoch 59/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.3479 - emotion_loss: 0.0734 - intensity_loss: 0.2602 - gender_loss: 0.0679 - emotion_accuracy: 0.9309 - intensity_accuracy: 0.8930 - gender_accuracy: 0.9721 - val_loss: 0.7544 - val_emotion_loss: 0.4209 - val_intensity_loss: 0.4105 - val_gender_loss: 0.1391 - val_emotion_accuracy: 0.7425 - val_intensity_accuracy: 0.8204 - val_gender_accuracy: 0.9566 - lr: 2.5000e-04
# Epoch 60/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.3504 - emotion_loss: 0.0726 - intensity_loss: 0.2718 - gender_loss: 0.0706 - emotion_accuracy: 0.9283 - intensity_accuracy: 0.8860 - gender_accuracy: 0.9725 - val_loss: 1.0776 - val_emotion_loss: 0.6750 - val_intensity_loss: 0.4741 - val_gender_loss: 0.3928 - val_emotion_accuracy: 0.6437 - val_intensity_accuracy: 0.7590 - val_gender_accuracy: 0.8982 - lr: 2.5000e-04
# Epoch 61/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.3561 - emotion_loss: 0.0802 - intensity_loss: 0.2655 - gender_loss: 0.0740 - emotion_accuracy: 0.9261 - intensity_accuracy: 0.8852 - gender_accuracy: 0.9725 - val_loss: 0.8622 - val_emotion_loss: 0.5193 - val_intensity_loss: 0.4320 - val_gender_loss: 0.1611 - val_emotion_accuracy: 0.7186 - val_intensity_accuracy: 0.7904 - val_gender_accuracy: 0.9491 - lr: 2.5000e-04
# Epoch 62/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.3445 - emotion_loss: 0.0763 - intensity_loss: 0.2473 - gender_loss: 0.0658 - emotion_accuracy: 0.9328 - intensity_accuracy: 0.9001 - gender_accuracy: 0.9733 - val_loss: 0.6908 - val_emotion_loss: 0.3623 - val_intensity_loss: 0.4019 - val_gender_loss: 0.1369 - val_emotion_accuracy: 0.7829 - val_intensity_accuracy: 0.8278 - val_gender_accuracy: 0.9566 - lr: 2.5000e-04
# Epoch 63/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.3435 - emotion_loss: 0.0776 - intensity_loss: 0.2458 - gender_loss: 0.0598 - emotion_accuracy: 0.9309 - intensity_accuracy: 0.8975 - gender_accuracy: 0.9770 - val_loss: 0.8322 - val_emotion_loss: 0.4917 - val_intensity_loss: 0.4140 - val_gender_loss: 0.1825 - val_emotion_accuracy: 0.7096 - val_intensity_accuracy: 0.7949 - val_gender_accuracy: 0.9446 - lr: 2.5000e-04
# Epoch 64/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.3428 - emotion_loss: 0.0784 - intensity_loss: 0.2369 - gender_loss: 0.0691 - emotion_accuracy: 0.9250 - intensity_accuracy: 0.9045 - gender_accuracy: 0.9747 - val_loss: 0.8136 - val_emotion_loss: 0.4789 - val_intensity_loss: 0.3897 - val_gender_loss: 0.1927 - val_emotion_accuracy: 0.7156 - val_intensity_accuracy: 0.8039 - val_gender_accuracy: 0.9386 - lr: 2.5000e-04
# Epoch 65/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.3541 - emotion_loss: 0.0849 - intensity_loss: 0.2557 - gender_loss: 0.0673 - emotion_accuracy: 0.9235 - intensity_accuracy: 0.8967 - gender_accuracy: 0.9770 - val_loss: 0.8377 - val_emotion_loss: 0.4972 - val_intensity_loss: 0.4375 - val_gender_loss: 0.1525 - val_emotion_accuracy: 0.7260 - val_intensity_accuracy: 0.7919 - val_gender_accuracy: 0.9476 - lr: 2.5000e-04
# Epoch 66/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.3467 - emotion_loss: 0.0830 - intensity_loss: 0.2422 - gender_loss: 0.0620 - emotion_accuracy: 0.9250 - intensity_accuracy: 0.9082 - gender_accuracy: 0.9792 - val_loss: 0.6697 - val_emotion_loss: 0.3250 - val_intensity_loss: 0.4532 - val_gender_loss: 0.1521 - val_emotion_accuracy: 0.7949 - val_intensity_accuracy: 0.8009 - val_gender_accuracy: 0.9581 - lr: 2.5000e-04
# Epoch 67/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.3355 - emotion_loss: 0.0750 - intensity_loss: 0.2364 - gender_loss: 0.0579 - emotion_accuracy: 0.9309 - intensity_accuracy: 0.9071 - gender_accuracy: 0.9825 - val_loss: 0.7427 - val_emotion_loss: 0.3995 - val_intensity_loss: 0.4572 - val_gender_loss: 0.1418 - val_emotion_accuracy: 0.7859 - val_intensity_accuracy: 0.8069 - val_gender_accuracy: 0.9506 - lr: 2.5000e-04
# Epoch 68/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.3263 - emotion_loss: 0.0664 - intensity_loss: 0.2314 - gender_loss: 0.0657 - emotion_accuracy: 0.9346 - intensity_accuracy: 0.9168 - gender_accuracy: 0.9759 - val_loss: 0.7543 - val_emotion_loss: 0.4182 - val_intensity_loss: 0.4224 - val_gender_loss: 0.1620 - val_emotion_accuracy: 0.7829 - val_intensity_accuracy: 0.8204 - val_gender_accuracy: 0.9416 - lr: 2.5000e-04
# Epoch 69/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.3290 - emotion_loss: 0.0684 - intensity_loss: 0.2343 - gender_loss: 0.0678 - emotion_accuracy: 0.9331 - intensity_accuracy: 0.9131 - gender_accuracy: 0.9762 - val_loss: 0.7679 - val_emotion_loss: 0.4301 - val_intensity_loss: 0.4028 - val_gender_loss: 0.2029 - val_emotion_accuracy: 0.7829 - val_intensity_accuracy: 0.8159 - val_gender_accuracy: 0.9461 - lr: 2.5000e-04
# Epoch 70/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.3254 - emotion_loss: 0.0763 - intensity_loss: 0.2041 - gender_loss: 0.0590 - emotion_accuracy: 0.9276 - intensity_accuracy: 0.9142 - gender_accuracy: 0.9766 - val_loss: 0.7188 - val_emotion_loss: 0.3903 - val_intensity_loss: 0.4171 - val_gender_loss: 0.1381 - val_emotion_accuracy: 0.7620 - val_intensity_accuracy: 0.8473 - val_gender_accuracy: 0.9611 - lr: 2.5000e-04
# Epoch 71/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.3264 - emotion_loss: 0.0741 - intensity_loss: 0.2172 - gender_loss: 0.0588 - emotion_accuracy: 0.9313 - intensity_accuracy: 0.9194 - gender_accuracy: 0.9773 - val_loss: 0.6643 - val_emotion_loss: 0.3452 - val_intensity_loss: 0.3857 - val_gender_loss: 0.1416 - val_emotion_accuracy: 0.8189 - val_intensity_accuracy: 0.8159 - val_gender_accuracy: 0.9611 - lr: 2.5000e-04
# Epoch 72/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.3319 - emotion_loss: 0.0772 - intensity_loss: 0.2256 - gender_loss: 0.0612 - emotion_accuracy: 0.9331 - intensity_accuracy: 0.9123 - gender_accuracy: 0.9751 - val_loss: 0.7908 - val_emotion_loss: 0.4716 - val_intensity_loss: 0.3926 - val_gender_loss: 0.1346 - val_emotion_accuracy: 0.7590 - val_intensity_accuracy: 0.8383 - val_gender_accuracy: 0.9626 - lr: 2.5000e-04
# Epoch 73/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.3271 - emotion_loss: 0.0709 - intensity_loss: 0.2274 - gender_loss: 0.0679 - emotion_accuracy: 0.9316 - intensity_accuracy: 0.9045 - gender_accuracy: 0.9725 - val_loss: 0.6798 - val_emotion_loss: 0.3515 - val_intensity_loss: 0.4066 - val_gender_loss: 0.1604 - val_emotion_accuracy: 0.7964 - val_intensity_accuracy: 0.8293 - val_gender_accuracy: 0.9551 - lr: 2.5000e-04
# Epoch 74/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.3096 - emotion_loss: 0.0651 - intensity_loss: 0.1996 - gender_loss: 0.0532 - emotion_accuracy: 0.9383 - intensity_accuracy: 0.9238 - gender_accuracy: 0.9792 - val_loss: 0.8461 - val_emotion_loss: 0.5279 - val_intensity_loss: 0.3753 - val_gender_loss: 0.1595 - val_emotion_accuracy: 0.7275 - val_intensity_accuracy: 0.8293 - val_gender_accuracy: 0.9566 - lr: 2.5000e-04
# Epoch 75/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.3087 - emotion_loss: 0.0641 - intensity_loss: 0.2041 - gender_loss: 0.0503 - emotion_accuracy: 0.9447 - intensity_accuracy: 0.9168 - gender_accuracy: 0.9837 - val_loss: 0.7254 - val_emotion_loss: 0.3988 - val_intensity_loss: 0.4048 - val_gender_loss: 0.1612 - val_emotion_accuracy: 0.7784 - val_intensity_accuracy: 0.8189 - val_gender_accuracy: 0.9551 - lr: 2.5000e-04
# Epoch 76/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.3164 - emotion_loss: 0.0708 - intensity_loss: 0.2029 - gender_loss: 0.0598 - emotion_accuracy: 0.9391 - intensity_accuracy: 0.9205 - gender_accuracy: 0.9799 - val_loss: 0.6579 - val_emotion_loss: 0.3576 - val_intensity_loss: 0.3297 - val_gender_loss: 0.1451 - val_emotion_accuracy: 0.8009 - val_intensity_accuracy: 0.8503 - val_gender_accuracy: 0.9596 - lr: 2.5000e-04
# Epoch 77/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.3225 - emotion_loss: 0.0722 - intensity_loss: 0.2065 - gender_loss: 0.0805 - emotion_accuracy: 0.9368 - intensity_accuracy: 0.9164 - gender_accuracy: 0.9695 - val_loss: 0.6821 - val_emotion_loss: 0.3829 - val_intensity_loss: 0.3428 - val_gender_loss: 0.1219 - val_emotion_accuracy: 0.7605 - val_intensity_accuracy: 0.8323 - val_gender_accuracy: 0.9641 - lr: 2.5000e-04
# Epoch 78/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.3079 - emotion_loss: 0.0666 - intensity_loss: 0.1934 - gender_loss: 0.0577 - emotion_accuracy: 0.9409 - intensity_accuracy: 0.9305 - gender_accuracy: 0.9785 - val_loss: 0.5988 - val_emotion_loss: 0.2999 - val_intensity_loss: 0.3497 - val_gender_loss: 0.1130 - val_emotion_accuracy: 0.8249 - val_intensity_accuracy: 0.8443 - val_gender_accuracy: 0.9701 - lr: 2.5000e-04
# Epoch 79/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.2929 - emotion_loss: 0.0524 - intensity_loss: 0.1937 - gender_loss: 0.0563 - emotion_accuracy: 0.9491 - intensity_accuracy: 0.9231 - gender_accuracy: 0.9792 - val_loss: 0.6937 - val_emotion_loss: 0.3663 - val_intensity_loss: 0.3440 - val_gender_loss: 0.2671 - val_emotion_accuracy: 0.8069 - val_intensity_accuracy: 0.8533 - val_gender_accuracy: 0.9281 - lr: 2.5000e-04
# Epoch 80/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.3359 - emotion_loss: 0.0909 - intensity_loss: 0.2070 - gender_loss: 0.0602 - emotion_accuracy: 0.9157 - intensity_accuracy: 0.9164 - gender_accuracy: 0.9796 - val_loss: 1.1196 - val_emotion_loss: 0.6454 - val_intensity_loss: 0.4774 - val_gender_loss: 0.8009 - val_emotion_accuracy: 0.7111 - val_intensity_accuracy: 0.7964 - val_gender_accuracy: 0.8413 - lr: 2.5000e-04
# Epoch 81/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.3086 - emotion_loss: 0.0675 - intensity_loss: 0.1916 - gender_loss: 0.0660 - emotion_accuracy: 0.9413 - intensity_accuracy: 0.9276 - gender_accuracy: 0.9762 - val_loss: 0.7041 - val_emotion_loss: 0.4082 - val_intensity_loss: 0.3082 - val_gender_loss: 0.1670 - val_emotion_accuracy: 0.7500 - val_intensity_accuracy: 0.8698 - val_gender_accuracy: 0.9536 - lr: 2.5000e-04
# Epoch 82/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.2940 - emotion_loss: 0.0620 - intensity_loss: 0.1758 - gender_loss: 0.0477 - emotion_accuracy: 0.9450 - intensity_accuracy: 0.9309 - gender_accuracy: 0.9837 - val_loss: 0.9512 - val_emotion_loss: 0.6268 - val_intensity_loss: 0.3467 - val_gender_loss: 0.2545 - val_emotion_accuracy: 0.6841 - val_intensity_accuracy: 0.8548 - val_gender_accuracy: 0.9251 - lr: 2.5000e-04
# Epoch 83/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.2958 - emotion_loss: 0.0620 - intensity_loss: 0.1827 - gender_loss: 0.0490 - emotion_accuracy: 0.9413 - intensity_accuracy: 0.9305 - gender_accuracy: 0.9829 - val_loss: 0.7794 - val_emotion_loss: 0.4666 - val_intensity_loss: 0.3260 - val_gender_loss: 0.2309 - val_emotion_accuracy: 0.7395 - val_intensity_accuracy: 0.8533 - val_gender_accuracy: 0.9326 - lr: 2.5000e-04
# Epoch 84/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.2841 - emotion_loss: 0.0533 - intensity_loss: 0.1704 - gender_loss: 0.0564 - emotion_accuracy: 0.9547 - intensity_accuracy: 0.9354 - gender_accuracy: 0.9788 - val_loss: 0.5916 - val_emotion_loss: 0.2932 - val_intensity_loss: 0.3527 - val_gender_loss: 0.1226 - val_emotion_accuracy: 0.8338 - val_intensity_accuracy: 0.8398 - val_gender_accuracy: 0.9656 - lr: 2.5000e-04
# Epoch 85/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.2842 - emotion_loss: 0.0583 - intensity_loss: 0.1588 - gender_loss: 0.0524 - emotion_accuracy: 0.9454 - intensity_accuracy: 0.9402 - gender_accuracy: 0.9840 - val_loss: 0.6060 - val_emotion_loss: 0.3049 - val_intensity_loss: 0.3585 - val_gender_loss: 0.1305 - val_emotion_accuracy: 0.8293 - val_intensity_accuracy: 0.8638 - val_gender_accuracy: 0.9596 - lr: 2.5000e-04
# Epoch 86/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.2766 - emotion_loss: 0.0535 - intensity_loss: 0.1556 - gender_loss: 0.0466 - emotion_accuracy: 0.9510 - intensity_accuracy: 0.9395 - gender_accuracy: 0.9840 - val_loss: 1.1749 - val_emotion_loss: 0.8747 - val_intensity_loss: 0.3569 - val_gender_loss: 0.1317 - val_emotion_accuracy: 0.6287 - val_intensity_accuracy: 0.8368 - val_gender_accuracy: 0.9566 - lr: 2.5000e-04
# Epoch 87/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.3192 - emotion_loss: 0.0810 - intensity_loss: 0.1976 - gender_loss: 0.0606 - emotion_accuracy: 0.9328 - intensity_accuracy: 0.9231 - gender_accuracy: 0.9799 - val_loss: 0.7071 - val_emotion_loss: 0.4028 - val_intensity_loss: 0.3475 - val_gender_loss: 0.1673 - val_emotion_accuracy: 0.7784 - val_intensity_accuracy: 0.8503 - val_gender_accuracy: 0.9356 - lr: 2.5000e-04
# Epoch 88/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.2897 - emotion_loss: 0.0649 - intensity_loss: 0.1609 - gender_loss: 0.0507 - emotion_accuracy: 0.9413 - intensity_accuracy: 0.9380 - gender_accuracy: 0.9811 - val_loss: 0.7062 - val_emotion_loss: 0.4234 - val_intensity_loss: 0.2913 - val_gender_loss: 0.1472 - val_emotion_accuracy: 0.7515 - val_intensity_accuracy: 0.8728 - val_gender_accuracy: 0.9611 - lr: 2.5000e-04
# Epoch 89/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.3021 - emotion_loss: 0.0714 - intensity_loss: 0.1787 - gender_loss: 0.0563 - emotion_accuracy: 0.9406 - intensity_accuracy: 0.9298 - gender_accuracy: 0.9785 - val_loss: 0.7404 - val_emotion_loss: 0.4146 - val_intensity_loss: 0.4155 - val_gender_loss: 0.1773 - val_emotion_accuracy: 0.7530 - val_intensity_accuracy: 0.8293 - val_gender_accuracy: 0.9446 - lr: 2.5000e-04
# Epoch 90/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.2864 - emotion_loss: 0.0617 - intensity_loss: 0.1578 - gender_loss: 0.0594 - emotion_accuracy: 0.9439 - intensity_accuracy: 0.9339 - gender_accuracy: 0.9751 - val_loss: 0.5903 - val_emotion_loss: 0.3060 - val_intensity_loss: 0.2895 - val_gender_loss: 0.1620 - val_emotion_accuracy: 0.8114 - val_intensity_accuracy: 0.8787 - val_gender_accuracy: 0.9566 - lr: 2.5000e-04
# Epoch 91/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.3265 - emotion_loss: 0.0933 - intensity_loss: 0.1871 - gender_loss: 0.0581 - emotion_accuracy: 0.9146 - intensity_accuracy: 0.9279 - gender_accuracy: 0.9788 - val_loss: 1.4288 - val_emotion_loss: 0.9828 - val_intensity_loss: 0.4783 - val_gender_loss: 0.6852 - val_emotion_accuracy: 0.6033 - val_intensity_accuracy: 0.7949 - val_gender_accuracy: 0.8743 - lr: 2.5000e-04
# Epoch 92/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.2959 - emotion_loss: 0.0693 - intensity_loss: 0.1678 - gender_loss: 0.0544 - emotion_accuracy: 0.9409 - intensity_accuracy: 0.9398 - gender_accuracy: 0.9814 - val_loss: 0.9715 - val_emotion_loss: 0.6676 - val_intensity_loss: 0.3245 - val_gender_loss: 0.2066 - val_emotion_accuracy: 0.7036 - val_intensity_accuracy: 0.8578 - val_gender_accuracy: 0.9491 - lr: 1.2500e-04
# Epoch 93/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.2834 - emotion_loss: 0.0622 - intensity_loss: 0.1497 - gender_loss: 0.0559 - emotion_accuracy: 0.9409 - intensity_accuracy: 0.9450 - gender_accuracy: 0.9814 - val_loss: 0.7615 - val_emotion_loss: 0.4696 - val_intensity_loss: 0.3138 - val_gender_loss: 0.1645 - val_emotion_accuracy: 0.7829 - val_intensity_accuracy: 0.8638 - val_gender_accuracy: 0.9626 - lr: 1.2500e-04
# Epoch 94/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.2836 - emotion_loss: 0.0615 - intensity_loss: 0.1587 - gender_loss: 0.0492 - emotion_accuracy: 0.9409 - intensity_accuracy: 0.9391 - gender_accuracy: 0.9829 - val_loss: 0.6819 - val_emotion_loss: 0.4014 - val_intensity_loss: 0.2910 - val_gender_loss: 0.1429 - val_emotion_accuracy: 0.7919 - val_intensity_accuracy: 0.8743 - val_gender_accuracy: 0.9641 - lr: 1.2500e-04
# Epoch 95/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.2664 - emotion_loss: 0.0504 - intensity_loss: 0.1371 - gender_loss: 0.0518 - emotion_accuracy: 0.9565 - intensity_accuracy: 0.9517 - gender_accuracy: 0.9803 - val_loss: 0.6552 - val_emotion_loss: 0.3769 - val_intensity_loss: 0.2976 - val_gender_loss: 0.1241 - val_emotion_accuracy: 0.8069 - val_intensity_accuracy: 0.8802 - val_gender_accuracy: 0.9626 - lr: 1.2500e-04
# Epoch 96/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.2732 - emotion_loss: 0.0583 - intensity_loss: 0.1362 - gender_loss: 0.0497 - emotion_accuracy: 0.9473 - intensity_accuracy: 0.9517 - gender_accuracy: 0.9833 - val_loss: 0.6859 - val_emotion_loss: 0.4099 - val_intensity_loss: 0.2894 - val_gender_loss: 0.1267 - val_emotion_accuracy: 0.7919 - val_intensity_accuracy: 0.8772 - val_gender_accuracy: 0.9701 - lr: 1.2500e-04
# Epoch 97/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.2660 - emotion_loss: 0.0502 - intensity_loss: 0.1437 - gender_loss: 0.0448 - emotion_accuracy: 0.9525 - intensity_accuracy: 0.9473 - gender_accuracy: 0.9863 - val_loss: 0.7109 - val_emotion_loss: 0.4369 - val_intensity_loss: 0.2747 - val_gender_loss: 0.1401 - val_emotion_accuracy: 0.7754 - val_intensity_accuracy: 0.8832 - val_gender_accuracy: 0.9656 - lr: 1.2500e-04
# Epoch 98/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.2887 - emotion_loss: 0.0661 - intensity_loss: 0.1587 - gender_loss: 0.0579 - emotion_accuracy: 0.9450 - intensity_accuracy: 0.9391 - gender_accuracy: 0.9792 - val_loss: 0.6488 - val_emotion_loss: 0.3753 - val_intensity_loss: 0.2809 - val_gender_loss: 0.1294 - val_emotion_accuracy: 0.8024 - val_intensity_accuracy: 0.8817 - val_gender_accuracy: 0.9671 - lr: 1.2500e-04
# Epoch 99/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.2666 - emotion_loss: 0.0536 - intensity_loss: 0.1361 - gender_loss: 0.0444 - emotion_accuracy: 0.9521 - intensity_accuracy: 0.9461 - gender_accuracy: 0.9855 - val_loss: 0.5828 - val_emotion_loss: 0.3144 - val_intensity_loss: 0.2659 - val_gender_loss: 0.1276 - val_emotion_accuracy: 0.8473 - val_intensity_accuracy: 0.8847 - val_gender_accuracy: 0.9596 - lr: 6.2500e-05
# Epoch 100/120
# 43/43 [==============================] - 3s 63ms/step - loss: 0.2673 - emotion_loss: 0.0483 - intensity_loss: 0.1464 - gender_loss: 0.0600 - emotion_accuracy: 0.9562 - intensity_accuracy: 0.9417 - gender_accuracy: 0.9822 - val_loss: 0.6018 - val_emotion_loss: 0.3324 - val_intensity_loss: 0.2632 - val_gender_loss: 0.1371 - val_emotion_accuracy: 0.8189 - val_intensity_accuracy: 0.8922 - val_gender_accuracy: 0.9581 - lr: 6.2500e-05
# Epoch 101/120
# 43/43 [==============================] - 3s 64ms/step - loss: 0.2648 - emotion_loss: 0.0509 - intensity_loss: 0.1326 - gender_loss: 0.0559 - emotion_accuracy: 0.9547 - intensity_accuracy: 0.9506 - gender_accuracy: 0.9825 - val_loss: 0.6112 - val_emotion_loss: 0.3482 - val_intensity_loss: 0.2464 - val_gender_loss: 0.1313 - val_emotion_accuracy: 0.8338 - val_intensity_accuracy: 0.8922 - val_gender_accuracy: 0.9641 - lr: 6.2500e-05
# Epoch 102/120
# 43/43 [==============================] - 3s 63ms/step - loss: 0.2730 - emotion_loss: 0.0569 - intensity_loss: 0.1425 - gender_loss: 0.0526 - emotion_accuracy: 0.9461 - intensity_accuracy: 0.9461 - gender_accuracy: 0.9807 - val_loss: 0.6336 - val_emotion_loss: 0.3660 - val_intensity_loss: 0.2527 - val_gender_loss: 0.1457 - val_emotion_accuracy: 0.8024 - val_intensity_accuracy: 0.8892 - val_gender_accuracy: 0.9671 - lr: 6.2500e-05
# Epoch 103/120
# 43/43 [==============================] - 3s 62ms/step - loss: 0.2628 - emotion_loss: 0.0507 - intensity_loss: 0.1336 - gender_loss: 0.0472 - emotion_accuracy: 0.9528 - intensity_accuracy: 0.9491 - gender_accuracy: 0.9840 - val_loss: 0.5988 - val_emotion_loss: 0.3316 - val_intensity_loss: 0.2552 - val_gender_loss: 0.1406 - val_emotion_accuracy: 0.8278 - val_intensity_accuracy: 0.8892 - val_gender_accuracy: 0.9656 - lr: 6.2500e-05
# Epoch 104/120
# 43/43 [==============================] - 3s 63ms/step - loss: 0.2637 - emotion_loss: 0.0499 - intensity_loss: 0.1333 - gender_loss: 0.0571 - emotion_accuracy: 0.9551 - intensity_accuracy: 0.9473 - gender_accuracy: 0.9803 - val_loss: 0.6033 - val_emotion_loss: 0.3348 - val_intensity_loss: 0.2677 - val_gender_loss: 0.1289 - val_emotion_accuracy: 0.8308 - val_intensity_accuracy: 0.8967 - val_gender_accuracy: 0.9611 - lr: 6.2500e-05
# Epoch 105/120
# 43/43 [==============================] - 3s 63ms/step - loss: 0.2551 - emotion_loss: 0.0442 - intensity_loss: 0.1306 - gender_loss: 0.0474 - emotion_accuracy: 0.9606 - intensity_accuracy: 0.9487 - gender_accuracy: 0.9833 - val_loss: 0.5869 - val_emotion_loss: 0.3173 - val_intensity_loss: 0.2720 - val_gender_loss: 0.1290 - val_emotion_accuracy: 0.8428 - val_intensity_accuracy: 0.8952 - val_gender_accuracy: 0.9626 - lr: 6.2500e-05
# Epoch 106/120
# 43/43 [==============================] - 3s 61ms/step - loss: 0.2551 - emotion_loss: 0.0462 - intensity_loss: 0.1219 - gender_loss: 0.0515 - emotion_accuracy: 0.9584 - intensity_accuracy: 0.9536 - gender_accuracy: 0.9807 - val_loss: 0.6059 - val_emotion_loss: 0.3418 - val_intensity_loss: 0.2561 - val_gender_loss: 0.1261 - val_emotion_accuracy: 0.8413 - val_intensity_accuracy: 0.8982 - val_gender_accuracy: 0.9626 - lr: 6.2500e-05
# Epoch 107/120
# 43/43 [==============================] - 3s 60ms/step - loss: 0.2575 - emotion_loss: 0.0454 - intensity_loss: 0.1400 - gender_loss: 0.0406 - emotion_accuracy: 0.9558 - intensity_accuracy: 0.9536 - gender_accuracy: 0.9885 - val_loss: 0.5926 - val_emotion_loss: 0.3287 - val_intensity_loss: 0.2551 - val_gender_loss: 0.1272 - val_emotion_accuracy: 0.8353 - val_intensity_accuracy: 0.8982 - val_gender_accuracy: 0.9626 - lr: 3.1250e-05
# Epoch 108/120
# ...
# Epoch 75/120
# 42/42 [==============================] - 3s 64ms/step - loss: 0.2198 - emotion_loss: 0.0367 - intensity_loss: 0.0775 - gender_loss: 0.0384 - emotion_accuracy: 0.9646 - intensity_accuracy: 0.9702 - gender_accuracy: 0.9873 - val_loss: 0.7009 - val_emotion_loss: 0.3487 - val_intensity_loss: 0.6348 - val_gender_loss: 0.0506 - val_emotion_accuracy: 0.8366 - val_intensity_accuracy: 0.7994 - val_gender_accuracy: 0.9911 - lr: 2.5000e-04
# Epoch 76/120
# 42/42 [==============================] - 3s 63ms/step - loss: 0.2167 - emotion_loss: 0.0367 - intensity_loss: 0.0734 - gender_loss: 0.0338 - emotion_accuracy: 0.9665 - intensity_accuracy: 0.9706 - gender_accuracy: 0.9892 - val_loss: 0.6068 - val_emotion_loss: 0.3375 - val_intensity_loss: 0.3493 - val_gender_loss: 0.0681 - val_emotion_accuracy: 0.8470 - val_intensity_accuracy: 0.8945 - val_gender_accuracy: 0.9911 - lr: 2.5000e-04
# Epoch 77/120
# 42/42 [==============================] - 3s 63ms/step - loss: 0.2132 - emotion_loss: 0.0345 - intensity_loss: 0.0696 - gender_loss: 0.0360 - emotion_accuracy: 0.9646 - intensity_accuracy: 0.9736 - gender_accuracy: 0.9877 - val_loss: 0.6023 - val_emotion_loss: 0.3273 - val_intensity_loss: 0.3807 - val_gender_loss: 0.0517 - val_emotion_accuracy: 0.8529 - val_intensity_accuracy: 0.8796 - val_gender_accuracy: 0.9911 - lr: 1.2500e-04
# Epoch 78/120
# 42/42 [==============================] - 3s 62ms/step - loss: 0.2105 - emotion_loss: 0.0303 - intensity_loss: 0.0770 - gender_loss: 0.0344 - emotion_accuracy: 0.9725 - intensity_accuracy: 0.9691 - gender_accuracy: 0.9881 - val_loss: 0.6356 - val_emotion_loss: 0.3673 - val_intensity_loss: 0.3660 - val_gender_loss: 0.0429 - val_emotion_accuracy: 0.8484 - val_intensity_accuracy: 0.8782 - val_gender_accuracy: 0.9911 - lr: 1.2500e-04
# Epoch 79/120
# 42/42 [==============================] - 3s 61ms/step - loss: 0.2141 - emotion_loss: 0.0356 - intensity_loss: 0.0722 - gender_loss: 0.0356 - emotion_accuracy: 0.9665 - intensity_accuracy: 0.9743 - gender_accuracy: 0.9866 - val_loss: 0.5930 - val_emotion_loss: 0.3420 - val_intensity_loss: 0.3136 - val_gender_loss: 0.0374 - val_emotion_accuracy: 0.8499 - val_intensity_accuracy: 0.9004 - val_gender_accuracy: 0.9896 - lr: 1.2500e-04
# Epoch 80/120
# 42/42 [==============================] - 3s 63ms/step - loss: 0.2131 - emotion_loss: 0.0329 - intensity_loss: 0.0784 - gender_loss: 0.0374 - emotion_accuracy: 0.9699 - intensity_accuracy: 0.9739 - gender_accuracy: 0.9877 - val_loss: 0.6292 - val_emotion_loss: 0.3379 - val_intensity_loss: 0.4378 - val_gender_loss: 0.0553 - val_emotion_accuracy: 0.8336 - val_intensity_accuracy: 0.8722 - val_gender_accuracy: 0.9911 - lr: 1.2500e-04
# Epoch 81/120
# 42/42 [==============================] - 3s 64ms/step - loss: 0.2053 - emotion_loss: 0.0303 - intensity_loss: 0.0693 - gender_loss: 0.0272 - emotion_accuracy: 0.9736 - intensity_accuracy: 0.9754 - gender_accuracy: 0.9918 - val_loss: 0.6364 - val_emotion_loss: 0.3811 - val_intensity_loss: 0.3341 - val_gender_loss: 0.0329 - val_emotion_accuracy: 0.8306 - val_intensity_accuracy: 0.8945 - val_gender_accuracy: 0.9851 - lr: 1.2500e-04
# Epoch 82/120
# 42/42 [==============================] - 3s 65ms/step - loss: 0.2117 - emotion_loss: 0.0371 - intensity_loss: 0.0633 - gender_loss: 0.0369 - emotion_accuracy: 0.9665 - intensity_accuracy: 0.9766 - gender_accuracy: 0.9870 - val_loss: 0.7052 - val_emotion_loss: 0.3494 - val_intensity_loss: 0.6778 - val_gender_loss: 0.0222 - val_emotion_accuracy: 0.8440 - val_intensity_accuracy: 0.7979 - val_gender_accuracy: 0.9911 - lr: 1.2500e-04
# Epoch 83/120
# 42/42 [==============================] - 3s 64ms/step - loss: 0.2062 - emotion_loss: 0.0305 - intensity_loss: 0.0684 - gender_loss: 0.0371 - emotion_accuracy: 0.9710 - intensity_accuracy: 0.9777 - gender_accuracy: 0.9885 - val_loss: 0.6206 - val_emotion_loss: 0.3622 - val_intensity_loss: 0.3559 - val_gender_loss: 0.0208 - val_emotion_accuracy: 0.8574 - val_intensity_accuracy: 0.8945 - val_gender_accuracy: 0.9926 - lr: 1.2500e-04
# Epoch 84/120
# 42/42 [==============================] - 3s 64ms/step - loss: 0.2098 - emotion_loss: 0.0357 - intensity_loss: 0.0671 - gender_loss: 0.0339 - emotion_accuracy: 0.9687 - intensity_accuracy: 0.9751 - gender_accuracy: 0.9892 - val_loss: 0.6256 - val_emotion_loss: 0.3519 - val_intensity_loss: 0.4020 - val_gender_loss: 0.0307 - val_emotion_accuracy: 0.8455 - val_intensity_accuracy: 0.8915 - val_gender_accuracy: 0.9926 - lr: 1.2500e-04
# Epoch 85/120
# 42/42 [==============================] - 3s 62ms/step - loss: 0.2038 - emotion_loss: 0.0309 - intensity_loss: 0.0641 - gender_loss: 0.0345 - emotion_accuracy: 0.9751 - intensity_accuracy: 0.9780 - gender_accuracy: 0.9877 - val_loss: 0.5969 - val_emotion_loss: 0.3478 - val_intensity_loss: 0.3036 - val_gender_loss: 0.0580 - val_emotion_accuracy: 0.8425 - val_intensity_accuracy: 0.8900 - val_gender_accuracy: 0.9881 - lr: 1.2500e-04
# Epoch 86/120
# 42/42 [==============================] - 3s 62ms/step - loss: 0.1998 - emotion_loss: 0.0269 - intensity_loss: 0.0673 - gender_loss: 0.0323 - emotion_accuracy: 0.9739 - intensity_accuracy: 0.9747 - gender_accuracy: 0.9892 - val_loss: 0.6530 - val_emotion_loss: 0.4018 - val_intensity_loss: 0.3197 - val_gender_loss: 0.0464 - val_emotion_accuracy: 0.8187 - val_intensity_accuracy: 0.8960 - val_gender_accuracy: 0.9911 - lr: 1.2500e-04
# Epoch 87/120
# 42/42 [==============================] - 3s 64ms/step - loss: 0.1999 - emotion_loss: 0.0280 - intensity_loss: 0.0625 - gender_loss: 0.0370 - emotion_accuracy: 0.9751 - intensity_accuracy: 0.9806 - gender_accuracy: 0.9888 - val_loss: 0.6472 - val_emotion_loss: 0.3911 - val_intensity_loss: 0.3535 - val_gender_loss: 0.0227 - val_emotion_accuracy: 0.8306 - val_intensity_accuracy: 0.8930 - val_gender_accuracy: 0.9911 - lr: 1.2500e-04
# Epoch 88/120
# 42/42 [==============================] - 3s 63ms/step - loss: 0.1971 - emotion_loss: 0.0266 - intensity_loss: 0.0633 - gender_loss: 0.0315 - emotion_accuracy: 0.9751 - intensity_accuracy: 0.9780 - gender_accuracy: 0.9896 - val_loss: 0.6631 - val_emotion_loss: 0.3807 - val_intensity_loss: 0.4325 - val_gender_loss: 0.0381 - val_emotion_accuracy: 0.8217 - val_intensity_accuracy: 0.8796 - val_gender_accuracy: 0.9911 - lr: 1.2500e-04
# Epoch 89/120
# 42/42 [==============================] - 3s 64ms/step - loss: 0.1987 - emotion_loss: 0.0306 - intensity_loss: 0.0561 - gender_loss: 0.0328 - emotion_accuracy: 0.9687 - intensity_accuracy: 0.9788 - gender_accuracy: 0.9881 - val_loss: 0.6327 - val_emotion_loss: 0.3409 - val_intensity_loss: 0.4775 - val_gender_loss: 0.0203 - val_emotion_accuracy: 0.8618 - val_intensity_accuracy: 0.8663 - val_gender_accuracy: 0.9896 - lr: 1.2500e-04
# Epoch 90/120
# 42/42 [==============================] - 3s 64ms/step - loss: 0.2017 - emotion_loss: 0.0304 - intensity_loss: 0.0736 - gender_loss: 0.0249 - emotion_accuracy: 0.9699 - intensity_accuracy: 0.9743 - gender_accuracy: 0.9911 - val_loss: 0.6582 - val_emotion_loss: 0.3634 - val_intensity_loss: 0.4872 - val_gender_loss: 0.0234 - val_emotion_accuracy: 0.8262 - val_intensity_accuracy: 0.8722 - val_gender_accuracy: 0.9911 - lr: 1.2500e-04
# Epoch 91/120
# 42/42 [==============================] - 3s 63ms/step - loss: 0.2015 - emotion_loss: 0.0342 - intensity_loss: 0.0579 - gender_loss: 0.0307 - emotion_accuracy: 0.9676 - intensity_accuracy: 0.9788 - gender_accuracy: 0.9885 - val_loss: 0.7228 - val_emotion_loss: 0.4790 - val_intensity_loss: 0.3113 - val_gender_loss: 0.0346 - val_emotion_accuracy: 0.8068 - val_intensity_accuracy: 0.9019 - val_gender_accuracy: 0.9911 - lr: 1.2500e-04
# Epoch 92/120
# 42/42 [==============================] - 3s 63ms/step - loss: 0.1922 - emotion_loss: 0.0269 - intensity_loss: 0.0578 - gender_loss: 0.0231 - emotion_accuracy: 0.9739 - intensity_accuracy: 0.9814 - gender_accuracy: 0.9933 - val_loss: 0.6573 - val_emotion_loss: 0.3947 - val_intensity_loss: 0.3743 - val_gender_loss: 0.0360 - val_emotion_accuracy: 0.8172 - val_intensity_accuracy: 0.8975 - val_gender_accuracy: 0.9896 - lr: 1.2500e-04
# Epoch 93/120
# 42/42 [==============================] - 3s 63ms/step - loss: 0.1989 - emotion_loss: 0.0323 - intensity_loss: 0.0588 - gender_loss: 0.0312 - emotion_accuracy: 0.9732 - intensity_accuracy: 0.9799 - gender_accuracy: 0.9900 - val_loss: 0.6101 - val_emotion_loss: 0.3380 - val_intensity_loss: 0.4061 - val_gender_loss: 0.0386 - val_emotion_accuracy: 0.8574 - val_intensity_accuracy: 0.8871 - val_gender_accuracy: 0.9911 - lr: 1.2500e-04
# Epoch 94/120
# 42/42 [==============================] - 3s 63ms/step - loss: 0.1961 - emotion_loss: 0.0288 - intensity_loss: 0.0627 - gender_loss: 0.0311 - emotion_accuracy: 0.9728 - intensity_accuracy: 0.9773 - gender_accuracy: 0.9870 - val_loss: 0.6784 - val_emotion_loss: 0.4308 - val_intensity_loss: 0.3280 - val_gender_loss: 0.0355 - val_emotion_accuracy: 0.8172 - val_intensity_accuracy: 0.9034 - val_gender_accuracy: 0.9911 - lr: 1.2500e-04
# Epoch 95/120
# 42/42 [==============================] - 3s 63ms/step - loss: 0.1978 - emotion_loss: 0.0331 - intensity_loss: 0.0579 - gender_loss: 0.0275 - emotion_accuracy: 0.9728 - intensity_accuracy: 0.9806 - gender_accuracy: 0.9900 - val_loss: 0.6793 - val_emotion_loss: 0.4021 - val_intensity_loss: 0.4364 - val_gender_loss: 0.0234 - val_emotion_accuracy: 0.8306 - val_intensity_accuracy: 0.8752 - val_gender_accuracy: 0.9896 - lr: 1.2500e-04
# Epoch 96/120
# 42/42 [==============================] - 3s 63ms/step - loss: 0.1893 - emotion_loss: 0.0278 - intensity_loss: 0.0485 - gender_loss: 0.0275 - emotion_accuracy: 0.9754 - intensity_accuracy: 0.9833 - gender_accuracy: 0.9922 - val_loss: 0.6296 - val_emotion_loss: 0.3834 - val_intensity_loss: 0.3351 - val_gender_loss: 0.0227 - val_emotion_accuracy: 0.8351 - val_intensity_accuracy: 0.9049 - val_gender_accuracy: 0.9911 - lr: 1.2500e-04
# Epoch 97/120
# 42/42 [==============================] - 3s 64ms/step - loss: 0.1854 - emotion_loss: 0.0206 - intensity_loss: 0.0604 - gender_loss: 0.0285 - emotion_accuracy: 0.9829 - intensity_accuracy: 0.9784 - gender_accuracy: 0.9914 - val_loss: 0.6327 - val_emotion_loss: 0.3742 - val_intensity_loss: 0.3718 - val_gender_loss: 0.0304 - val_emotion_accuracy: 0.8380 - val_intensity_accuracy: 0.8990 - val_gender_accuracy: 0.9926 - lr: 6.2500e-05
# Epoch 98/120
# 42/42 [==============================] - 3s 63ms/step - loss: 0.1907 - emotion_loss: 0.0248 - intensity_loss: 0.0645 - gender_loss: 0.0289 - emotion_accuracy: 0.9713 - intensity_accuracy: 0.9769 - gender_accuracy: 0.9888 - val_loss: 0.6164 - val_emotion_loss: 0.3579 - val_intensity_loss: 0.3684 - val_gender_loss: 0.0372 - val_emotion_accuracy: 0.8529 - val_intensity_accuracy: 0.9019 - val_gender_accuracy: 0.9911 - lr: 6.2500e-05
# Epoch 99/120
# 42/42 [==============================] - 3s 63ms/step - loss: 0.1912 - emotion_loss: 0.0261 - intensity_loss: 0.0614 - gender_loss: 0.0312 - emotion_accuracy: 0.9784 - intensity_accuracy: 0.9795 - gender_accuracy: 0.9877 - val_loss: 0.6215 - val_emotion_loss: 0.3668 - val_intensity_loss: 0.3448 - val_gender_loss: 0.0547 - val_emotion_accuracy: 0.8410 - val_intensity_accuracy: 0.8990 - val_gender_accuracy: 0.9911 - lr: 6.2500e-05
# Epoch 100/120
# 42/42 [==============================] - 3s 63ms/step - loss: 0.1868 - emotion_loss: 0.0259 - intensity_loss: 0.0546 - gender_loss: 0.0214 - emotion_accuracy: 0.9721 - intensity_accuracy: 0.9829 - gender_accuracy: 0.9922 - val_loss: 0.6077 - val_emotion_loss: 0.3608 - val_intensity_loss: 0.3222 - val_gender_loss: 0.0508 - val_emotion_accuracy: 0.8395 - val_intensity_accuracy: 0.9079 - val_gender_accuracy: 0.9896 - lr: 6.2500e-05
# Epoch 101/120
# 42/42 [==============================] - 3s 63ms/step - loss: 0.1864 - emotion_loss: 0.0258 - intensity_loss: 0.0489 - gender_loss: 0.0296 - emotion_accuracy: 0.9773 - intensity_accuracy: 0.9825 - gender_accuracy: 0.9900 - val_loss: 0.6635 - val_emotion_loss: 0.3794 - val_intensity_loss: 0.4608 - val_gender_loss: 0.0303 - val_emotion_accuracy: 0.8351 - val_intensity_accuracy: 0.8767 - val_gender_accuracy: 0.9926 - lr: 6.2500e-05
# Epoch 102/120
# 42/42 [==============================] - 3s 63ms/step - loss: 0.1860 - emotion_loss: 0.0262 - intensity_loss: 0.0538 - gender_loss: 0.0197 - emotion_accuracy: 0.9777 - intensity_accuracy: 0.9777 - gender_accuracy: 0.9940 - val_loss: 0.6627 - val_emotion_loss: 0.3809 - val_intensity_loss: 0.4608 - val_gender_loss: 0.0200 - val_emotion_accuracy: 0.8380 - val_intensity_accuracy: 0.8811 - val_gender_accuracy: 0.9955 - lr: 6.2500e-05
# Epoch 103/120
# 42/42 [==============================] - 3s 62ms/step - loss: 0.1905 - emotion_loss: 0.0303 - intensity_loss: 0.0505 - gender_loss: 0.0282 - emotion_accuracy: 0.9721 - intensity_accuracy: 0.9825 - gender_accuracy: 0.9900 - val_loss: 0.6685 - val_emotion_loss: 0.3683 - val_intensity_loss: 0.5162 - val_gender_loss: 0.0304 - val_emotion_accuracy: 0.8291 - val_intensity_accuracy: 0.8588 - val_gender_accuracy: 0.9911 - lr: 6.2500e-05
# Epoch 104/120
# 42/42 [==============================] - 3s 63ms/step - loss: 0.1876 - emotion_loss: 0.0263 - intensity_loss: 0.0497 - gender_loss: 0.0358 - emotion_accuracy: 0.9754 - intensity_accuracy: 0.9836 - gender_accuracy: 0.9870 - val_loss: 0.6306 - val_emotion_loss: 0.3509 - val_intensity_loss: 0.4510 - val_gender_loss: 0.0264 - val_emotion_accuracy: 0.8395 - val_intensity_accuracy: 0.8811 - val_gender_accuracy: 0.9911 - lr: 3.1250e-05
# Epoch 105/120
# 42/42 [==============================] - 3s 62ms/step - loss: 0.1876 - emotion_loss: 0.0261 - intensity_loss: 0.0503 - gender_loss: 0.0363 - emotion_accuracy: 0.9743 - intensity_accuracy: 0.9833 - gender_accuracy: 0.9896 - val_loss: 0.6378 - val_emotion_loss: 0.3467 - val_intensity_loss: 0.4887 - val_gender_loss: 0.0275 - val_emotion_accuracy: 0.8514 - val_intensity_accuracy: 0.8767 - val_gender_accuracy: 0.9926 - lr: 3.1250e-05
# Epoch 106/120
# 42/42 [==============================] - 3s 63ms/step - loss: 0.1824 - emotion_loss: 0.0224 - intensity_loss: 0.0506 - gender_loss: 0.0293 - emotion_accuracy: 0.9799 - intensity_accuracy: 0.9847 - gender_accuracy: 0.9903 - val_loss: 0.6296 - val_emotion_loss: 0.3529 - val_intensity_loss: 0.4331 - val_gender_loss: 0.0393 - val_emotion_accuracy: 0.8484 - val_intensity_accuracy: 0.8871 - val_gender_accuracy: 0.9926 - lr: 3.1250e-05
# Epoch 107/120
# 42/42 [==============================] - 3s 63ms/step - loss: 0.1881 - emotion_loss: 0.0281 - intensity_loss: 0.0494 - gender_loss: 0.0317 - emotion_accuracy: 0.9732 - intensity_accuracy: 0.9821 - gender_accuracy: 0.9881 - val_loss: 0.6247 - val_emotion_loss: 0.3642 - val_intensity_loss: 0.3809 - val_gender_loss: 0.0374 - val_emotion_accuracy: 0.8425 - val_intensity_accuracy: 0.9019 - val_gender_accuracy: 0.9926 - lr: 3.1250e-05
# Epoch 108/120
# 42/42 [==============================] - 3s 63ms/step - loss: 0.1848 - emotion_loss: 0.0253 - intensity_loss: 0.0537 - gender_loss: 0.0239 - emotion_accuracy: 0.9743 - intensity_accuracy: 0.9814 - gender_accuracy: 0.9937 - val_loss: 0.6477 - val_emotion_loss: 0.3607 - val_intensity_loss: 0.4718 - val_gender_loss: 0.0343 - val_emotion_accuracy: 0.8455 - val_intensity_accuracy: 0.8752 - val_gender_accuracy: 0.9926 - lr: 3.1250e-05
# Epoch 109/120
# 42/42 [==============================] - 3s 63ms/step - loss: 0.1822 - emotion_loss: 0.0233 - intensity_loss: 0.0494 - gender_loss: 0.0279 - emotion_accuracy: 0.9769 - intensity_accuracy: 0.9799 - gender_accuracy: 0.9914 - val_loss: 0.6447 - val_emotion_loss: 0.3887 - val_intensity_loss: 0.3724 - val_gender_loss: 0.0289 - val_emotion_accuracy: 0.8351 - val_intensity_accuracy: 0.9034 - val_gender_accuracy: 0.9926 - lr: 3.1250e-05
#   emotion=0.8618  intensity=0.8663  gender=0.9896
#
# Emotion   mean=0.8791
# Intensity mean=0.8744
# Gender    mean=0.9774
# Best fold: 4

# %% [markdown]
# ## Step 4 — Evaluation

# %%
fig, axes = plt.subplots(1, 3, figsize=(22, 6))

cm_emo = confusion_matrix(best['true_emo'], best['pred_emo'])
sns.heatmap(cm_emo, annot=True, fmt='d', cmap='Blues',
            xticklabels=EMOTION_NAMES, yticklabels=EMOTION_NAMES, ax=axes[0])
axes[0].set_title(f'Emotion  acc={best["acc_emo"]:.4f}', fontsize=11)
axes[0].set_ylabel('True'); axes[0].set_xlabel('Predicted')
axes[0].tick_params(axis='x', rotation=45)

cm_int = confusion_matrix(best['true_int'], best['pred_int'])
sns.heatmap(cm_int, annot=True, fmt='d', cmap='Greens',
            xticklabels=INTENSITY_NAMES, yticklabels=INTENSITY_NAMES, ax=axes[1])
axes[1].set_title(f'Intensity  acc={best["acc_int"]:.4f}', fontsize=11)
axes[1].set_ylabel('True'); axes[1].set_xlabel('Predicted')

cm_gen = confusion_matrix(best['true_gen'], best['pred_gen'])
sns.heatmap(cm_gen, annot=True, fmt='d', cmap='Oranges',
            xticklabels=GENDER_NAMES, yticklabels=GENDER_NAMES, ax=axes[2])
axes[2].set_title(f'Gender  acc={best["acc_gen"]:.4f}', fontsize=11)
axes[2].set_ylabel('True'); axes[2].set_xlabel('Predicted')

plt.suptitle(f'Multi-task CNN — Fold {best["fold"]}', fontsize=13)
plt.tight_layout()
plt.show()

print('── Emotion ──')
print(classification_report(best['true_emo'], best['pred_emo'],
                            target_names=EMOTION_NAMES))
print('── Intensity ──')
print(classification_report(best['true_int'], best['pred_int'],
                            target_names=INTENSITY_NAMES))
print('── Gender ──')
print(classification_report(best['true_gen'], best['pred_gen'],
                            target_names=GENDER_NAMES))
# Out:
# ── Emotion ──
#               precision    recall  f1-score   support
#
#         calm       0.89      0.86      0.88        98
#        happy       0.91      0.80      0.85        76
#          sad       0.81      0.90      0.85        86
#        angry       0.90      0.93      0.91       108
#      fearful       0.97      0.98      0.98       104
#      disgust       0.98      0.90      0.94        97
#    surprised       0.90      1.00      0.95        75
#
#     accuracy                           0.91       644
#    macro avg       0.91      0.91      0.91       644
# weighted avg       0.91      0.91      0.91       644
#
# ── Intensity ──
#               precision    recall  f1-score   support
#
#       normal       0.76      0.99      0.86       313
#       strong       0.98      0.70      0.82       331
#
#     accuracy                           0.84       644
#    macro avg       0.87      0.85      0.84       644
# weighted avg       0.87      0.84      0.84       644
#
# ── Gender ──
#               precision    recall  f1-score   support
#
#         male       1.00      0.98      0.99       332
#       female       0.98      1.00      0.99       312
#
#     accuracy                           0.99       644
#    macro avg       0.99      0.99      0.99       644
# weighted avg       0.99      0.99      0.99       644

# %% [markdown]
# ## Step 5 — Save to models/

# %%
os.makedirs('models', exist_ok=True)
model.save(MODEL_PATH)
print(f'Saved: {MODEL_PATH}')
# Out:
# Saved: models\cnn_multitask.h5
